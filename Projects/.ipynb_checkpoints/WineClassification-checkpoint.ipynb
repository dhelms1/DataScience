# %%
# Regular EDA (exploratory data analysis) and plotting libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Data Manipulation Tools
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

# Models and Evaluations from Scikit-Learn
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.metrics import plot_roc_curve

# %% [markdown]
# ## Problem:
# * Can we predict the class of the wine with greater than 95% accuracy?

# %%
from sklearn.datasets import load_wine

columns = ['Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash', 'Magnesium', 'Total phenols', 'Flavanoids', 
           'Nonflavanoid phenols', 'Proanthocyanins', 'Color intensity', 'Hue', 'OD280/OD315 of diluted wines', 'Proline']


data, target = load_wine(return_X_y=True)
df = pd.DataFrame(data, columns=columns)
df['Target'] = target
df.head()
# Out:
#    Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    Flavanoids  Nonflavanoid phenols  Proanthocyanins  Color intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280/OD315 of diluted wines  Proline  Target
# ...

# %%
corr_matrix = df.corr()
fig, ax = plt.subplots(figsize=(15,10))
ax = sns.heatmap(corr_matrix, annot=True, linewidth=0.5, fmt='.2f', cmap='YlGnBu')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### Test multiple models

# %%
np.random.seed(42)

X = df.drop('Target', axis=1)
y = df['Target']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Normalize Training Data
train_scaler = MinMaxScaler()
train_scaler.fit(X_train)
X_train = train_scaler.transform(X_train)

# Normalize Test Data
test_scaler = MinMaxScaler()
test_scaler.fit(X_test)
X_test = test_scaler.transform(X_test)

def fit_and_score(models, X_train, X_test, y_train, y_test):
    """
    Fit and evaluate multiple machine learning models
    models: dictionary of different models to train and score
    NOTE: data is normalized before passing into function
    """
    model_scores = {}
    for name, model in models.items():
        model.fit(X_train, y_train)
        model_scores[name] = model.score(X_test, y_test)
    return model_scores
    
models = {'LinearSVC': LinearSVC(),
          'LogisticRegression': LogisticRegression(),
          'KNeighborsClassifier': KNeighborsClassifier(),
          'RandomForestClassifier': RandomForestClassifier()}

model_scores = fit_and_score(models, X_train, X_test, y_train, y_test)
model_scores
# Out:
# {'LinearSVC': 0.9722222222222222,
#  'LogisticRegression': 0.9722222222222222,
#  'KNeighborsClassifier': 0.9444444444444444,
#  'RandomForestClassifier': 0.9722222222222222}

# %% [markdown]
# ### Drop lowest scores and tune best models

# %%
np.random.seed(42)

svc_grid = {'C': np.logspace(-4, 4, 50),
            'max_iter': [20000]}
log_grid = {'C': np.logspace(-4, 4, 50),
            'solver': ['liblinear']}

def grid_search(model, grid):
    gs_model = GridSearchCV(model, param_grid=grid, cv=5, verbose=True)
    return gs_model

gs_log = grid_search(LogisticRegression(), log_grid)
gs_svc = grid_search(LinearSVC(), svc_grid)

gs_log.fit(X_train, y_train)
gs_svc.fit(X_train, y_train)

log_params = gs_log.best_params_
log_score = gs_log.score(X_test, y_test)
svc_params = gs_svc.best_params_
svc_score = gs_svc.score(X_test, y_test)

print('LogisticRegression best parameters:', log_params, '\nScore:', log_score)
print('LinearSVC best parameters:', svc_params, '\nScore:', svc_score)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 250 out of 250 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# LogisticRegression best parameters: {'C': 24.420530945486497, 'solver': 'liblinear'}
# Score: 0.9722222222222222
# LinearSVC best parameters: {'C': 5.428675439323859, 'max_iter': 20000}
# Score: 1.0
# [Parallel(n_jobs=1)]: Done 250 out of 250 | elapsed:    0.8s finished

# %% [markdown]
# ### Continue with LinearSVC model

# %%
y_preds = gs_svc.predict(X_test)

fig, ax = plt.subplots(figsize=(3,3))
ax = sns.heatmap(confusion_matrix(y_test, y_preds), annot=True, cbar=False)
plt.xlabel('True Label')
plt.ylabel('Predicted Label')
plt.show()

# %%
clf = LinearSVC(C=5.428675439323859, max_iter=20000)

def cross_validation_metrics(model, X, y):
    cv_acc = cross_val_score(model, X, y, scoring='accuracy')
    cv_recall = cross_val_score(model, X, y, scoring='recall')
    cv_f1 = cross_val_score(model, X, y, scoring='f1')
    cv_metrics = pd.DataFrame({'Accuracy': np.mean(cv_acc), 'Recall': np.mean(cv_recall),
                               'F1': np.mean(cv_f1)}, index=[0])
    return cv_metrics
    
linear_metrics = cross_validation_metrics (clf, X, y)
linear_metrics
# Out:
# C:\Users\derek\Miniconda3\lib\site-packages\sklearn\svm\_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\derek\Miniconda3\lib\site-packages\sklearn\svm\_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\derek\Miniconda3\lib\site-packages\sklearn\svm\_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\derek\Miniconda3\lib\site-packages\sklearn\svm\_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\derek\Miniconda3\lib\site-packages\sklearn\svm\_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
# ...
